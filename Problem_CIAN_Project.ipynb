# %% [markdown]
# <img src="https://pp.vk.me/c628718/v628718483/3eb9d/PmC9FjUvr-k.jpg" height="500" width="500">
#
# # <center> Анализ данных </center>
#
# ---
#
# ## <center>Data Mining course<br>Практический проект</center>
#
# <h6 style="text-align: right;" markdown="1">Slack: @dmitrysergeyev <br> [Github](https://github.com/DmitrySerg)</h6>

# %% [markdown]
# # Часть первая. Лирическая.
#
# ***
# ***
#
# Итак, вам нужно распарсить [CIAN.ru](http://cian.ru) и получить из него следующий список переменных по каждой квартирке из каждого округа Москвы
#
# - **N** – номер квартиры по порядку
# - **Rooms** – число комнат
# - **Price** – цена
# - **Totsp** – общая площадь квартиры, кв. м.
# - **Livesp** – жилая площадь квартиры, кв. м.
# - **Kitsp** – площадь кухни, кв. м.
# - **Dist** – расстояние от центра в км. (можно по Пифагору)
# - **Metrdist** – расстояние до метро в минутах
# - **Walk** – 1 – если пешком от метро, 0 – если на транспорте
# - **Brick** – 1 – кирпичный/монолит/жб, 0 – другой
# - **Tel** – 1 – если есть, 0 – нет
# - **Bal** – 1 – есть балкон/лоджия, 0 – нет
# - **Floor** – номер этажа, на котором расположена квартира
# - **Nfloors** – всего этажей в доме
# - **New** – 1 – первичный рынок, 0 - вторичка
#
# ---
#
# >### Для чего всё это нужно?
#
#
#
# **Во-первых**, написать свой первый (второй, третий...N+1) парсер, познакомиться получше с питоном и некоторыми его библиотеками.
#
# **Во-вторых**, получив такой датасетик можно будет заняться его обработкой, очисткой, визуализацией, и прочими радостями, которые обязательно сопровождают работу с данными
#
# **В-третьих**, на основании обработанных данных можно строить модели! Например, объясняющие цену квартирки, что поможет понять, кому и где на Руси жить хорошо, или по поиску аномалий и выбросов, чтобы узнать, где у нас есть недооцененное/переоцененное жильё.
#
# ---
#
# >### А если я уже всё умею/не хочу парсить ЦИАН/мне скучно
#
#
# В этом случае вам поможет...
# <img align="center" src="https://cdn.meme.am/instances/500x/67568225.jpg" height="300" width="300">
#
# Инициатива не наказуема - придумывайте свои проекты, которыми было бы интересно заняться, парсить можно очень много разных интересных вещей, так что предлагайте свои варианты. Но очень желательно, чтобы они также позволяли вам пройтись по основным этапам [работы](http://lurkmore.to/Работа) с данными - от получения и очистки, до моделирования.
#
# ---
#
# >###  Как парсить?/Что мне делать?/[АААААААА](http://memesmix.net/media/created/y1mpso.jpg)
#
#
# [Немношко](http://picademy.net/wp-content/uploads/2014/04/nemnoshk.png) кода, который позволит быстрее начать работу я уже выкладывал в канале `#_data_analysis` в Слаке, возможно, будет удобнее продолжать работать с ним, а возможно, вы ходите переписать всё по-своему, оба варианта абсолютно равноправны.
#
# * Если вам слишком просто - очень веселым опытом для вас может стать написание парсера в парадигме ООП, код получается красивее, трава зеленее, а головной боли и духа приключений - больше.
#
# * Если вам слишком тяжело - всегда можно [спросить](http://stackoverflow.com/), [спросить](https://www.python.org/doc/), [спросить](http://google.com), и, конечно, спрашивать в слаке меня и всех неравнодушных. Особенно много последних появится ближе к концу дедлайна.
#
#
# # Часть вторая. Оценочная.
#
# ***
# ***
#
# За всё про всё на курсе по дата майнингу можно будет получить 30 баллов:
#
# - 10 за парсер
# - 10 за исследование, очистку, визуализацию
# - 10 за модельки
#
# На данный момент стоит сосредоточиться на первых 10 баллах, срок на написание парсера - **2 недели**. То есть код и csv должны быть готовы к 10 ноября.
#
# Критерии:
# - 8 баллов - работающий парсер, который выгружает необходимый csv файл.
# - 1 балл - комментарии в коде, объясняющие, что он делает или почему это работает
# - 1 балл - структурированность кода, написание пользовательских функций
#
# <img align="center" src="http://cs620930.vk.me/v620930698/bfdb/-4ZL4Ytyips.jpg" height="300" width="300">
#
#
# # Часть третья. Торжественная.
#
# ***
# ***
#
# >###  Я молодец и всё сделал, а куда сдавать?
#
# Свой код, финальный .csv файл и (возможно, но сейчас не обязательно) ноутбук с предварительным анализом вам нужно загрузить на [Github](https://github.com/). Если аккаунта еще нет - самое время его создать. Наиболее безболезненный [туториал](https://guides.github.com/activities/hello-world/) по созданию своего первого репозитория есть на самом гитхабе.
#
# А дальше просто скиньте ссылку на свой репозиторий в гугл-док, который мы позднее вышлем вам на почту и скинем в слак.
#
#
# <img align="center" src="http://i.imgur.com/gZt2RLG.png" height="300" width="300">
